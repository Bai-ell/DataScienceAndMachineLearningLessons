# %% [markdown]
# #13. Рисуем линии уровня функциями contour, contourf и tricontour, tricontourf | Matplotlib уроки

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import numpy as np 
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(7, 4))

# %%
fig = plt.figure(figsize=(7, 4))

ax_3d = fig.add_subplot(111, projection='3d')


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




ax_3d.plot_surface(x_grid, y_grid, z_grid, rstride=5, cstride=3, alpha=0.5, cmap='viridis')

ax_3d.set_xlabel('X Label')
ax_3d.set_ylabel('Y Label')
ax_3d.set_zlabel('Z Label')
# Out:
# Text(0.5, 0, 'Z Label')

# %%
fig = plt.figure(figsize=(7, 4))

ax_3d = fig.add_subplot(111, projection='3d')


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




ax_3d.contour(x_grid, y_grid, z_grid, rstride=5, cstride=3, alpha=0.5, cmap='viridis')

ax_3d.set_xlabel('X Label')
ax_3d.set_ylabel('Y Label')
ax_3d.set_zlabel('Z Label')
# Out:
# /var/folders/07/56f70q6n70d3v657jsy7fjgr0000gn/T/ipykernel_28302/894107448.py:18: UserWarning: The following kwargs were not used by contour: 'rstride', 'cstride'
#   ax_3d.contour(x_grid, y_grid, z_grid, rstride=5, cstride=3, alpha=0.5, cmap='viridis')
# Text(0.5, 0, 'Z Label')

# %%
fig = plt.figure(figsize=(7, 4))

ax_3d = fig.add_subplot(111, projection='3d')


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




ax_3d.contourf(x_grid, y_grid, z_grid, rstride=5, cstride=3, alpha=0.5, cmap='viridis')

ax_3d.set_xlabel('X Label')
ax_3d.set_ylabel('Y Label')
ax_3d.set_zlabel('Z Label')
# Out:
# /var/folders/07/56f70q6n70d3v657jsy7fjgr0000gn/T/ipykernel_28302/1967264566.py:18: UserWarning: The following kwargs were not used by contour: 'rstride', 'cstride'
#   ax_3d.contourf(x_grid, y_grid, z_grid, rstride=5, cstride=3, alpha=0.5, cmap='viridis')
# Text(0.5, 0, 'Z Label')

# %%
fig, ax = plt.subplots(1 , 2)


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




ax[0].contour(x_grid, y_grid, z_grid)
ax[1].contourf(x_grid, y_grid, z_grid)

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid)
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 10 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, 15)
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 23 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, [-0.5, 0, 0.5])
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 5 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, colors='red')
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 10 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, colors=['g', 'b', 'r'])
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 10 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, cmap='plasma')
ax[1].contourf(x_grid, y_grid, z_grid)
ax[0].clabel(c1, inline=True, fontsize=8)
# Out:
# <a list of 10 text.Text objects>

# %%
fig, ax = plt.subplots(1 , 2, figsize=(7, 4))


x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)




z_grid = np.sin(x_grid) * np.sin(y_grid) / (x_grid * y_grid)




c1 = ax[0].contour(x_grid, y_grid, z_grid, cmpa='plasma')
ax[1].contourf(x_grid, y_grid, z_grid)
c1.clabel(colors='k', fontsize=8)
# Out:
# /var/folders/07/56f70q6n70d3v657jsy7fjgr0000gn/T/ipykernel_28302/4106592654.py:16: UserWarning: The following kwargs were not used by contour: 'cmpa'
#   c1 = ax[0].contour(x_grid, y_grid, z_grid, cmpa='plasma')
# <a list of 10 text.Text objects>

# %%
fig, ax = plt.subplots(figsize=(7, 4))






x = np.random.rand(100) * 4*np.pi - 2*np.pi
y = np.random.rand(100) * 4*np.pi - 2*np.pi



z = np.sin(x) * np.sin(y) / (1+np.abs(x*y))



c1 = ax.tricontour(x, y, z, cmpa='plasma')



c1.clabel(colors='k', fmt='%.2f')
# Out:
# /var/folders/07/56f70q6n70d3v657jsy7fjgr0000gn/T/ipykernel_28302/2337283010.py:17: UserWarning: The following kwargs were not used by contour: 'cmpa'
#   c1 = ax.tricontour(x, y, z, cmpa='plasma')
# <a list of 19 text.Text objects>

# %%
fig, ax = plt.subplots(figsize=(7, 4))






x = np.random.rand(100) * 4*np.pi - 2*np.pi
y = np.random.rand(100) * 4*np.pi - 2*np.pi



z = np.sin(x) * np.sin(y) / (1+np.abs(x*y))



c1 = ax.tricontourf(x, y, z, cmpa='plasma')



c1.clabel(colors='k', fmt='%.2f')
# Out:
# /var/folders/07/56f70q6n70d3v657jsy7fjgr0000gn/T/ipykernel_28302/2277070037.py:17: UserWarning: The following kwargs were not used by contour: 'cmpa'
#   c1 = ax.tricontourf(x, y, z, cmpa='plasma')
# <a list of 31 text.Text objects>
