# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import numpy as np 
from PIL import Image

# %%
img = Image.open('panda.jpg')

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot()

ax.imshow(img)



plt.show()

# %%
plt.imshow(img, cmap='gray', interpolation='nearest', aspect='equal', origin='lower', alpha=0.5)

# %%
b = plt.imshow(img, cmap='gray', interpolation='nearest', aspect='equal', origin='lower', alpha=0.5)


plt.colorbar(b)
