# %% [markdown]
# Автоэнкодеры. Часть 2

# %% [markdown]
# Свойства получившейся модели
#
# Компактный признаковый вектор обуславливает:
#
# хорошее признаковое представление;
# понижение размерности.
# Мы рассмотрели классический автокодировщик. А в разделе «Практика» текущего модуля рассмотрим существующие вариации автокодировщиков:
#
# Denoising Autoencoders, позволяющий отсеивать шум с картинки.
# Variational Autoencoders, решает проблемы интерпретации кода.

# %% [markdown]
# Дополнительные материалы
#
# nlp
# В качестве дополнительной литературы рекомендуем вам прочесть статью «Туда и обратно для нейронных сетей, или обзор применений автокодировщиков в анализе текстов»https://habr.com/ru/companies/antiplagiat/articles/418173/
