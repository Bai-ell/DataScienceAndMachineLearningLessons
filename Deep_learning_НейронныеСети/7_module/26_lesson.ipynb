# %% [markdown]
# В качестве закрепления материала предлагаем Вам решить 2 задачи:
#
# 1. Задача по детекции ядер клеток (ссылка на закрытое соревнование на площадке kaggle). https://www.kaggle.com/competitions/sf-dl-nucleus-detection
# В этом соревновании мы рекомендуем попробовать решения на U-Net или c DeepLab.
#
# 2. Задача по сегментации людей на фотографии (ссылка на закрытое соревнование на площадке kaggle).
# На котором вы можете попробовать немного другой подход в решении задачи сегментации, основываясь на этом Baseline;https://www.kaggle.com/code/itslek/baseline-keras-person-segmentation-v1-5?scriptVersionId=52352466
#
# Участие - индивидуальное. Обратите внимание, что у вас будет 5 сабмитов в сутки!
#
# Для участия в соревновании отводится 2 недели.
#
# В качестве опорной точки для построения модели к каждому соревнования представлен Baseline. А дальше вы можете применить все полученные знания, чтобы улучшить модель и повысить её результаты. Успехов в соревновании!
