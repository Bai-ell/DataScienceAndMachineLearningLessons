# %%
import seaborn as sns

# %%
penguins = sns.load_dataset('penguins')
type(penguins)
# Out:
# pandas.core.frame.DataFrame

# %%
penguins.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
ax = sns.scatterplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm' )

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax = sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter')

# %%
ax = sns.scatterplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm' )
ax = sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter')

# %%
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', col = 'sex')
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter', col = 'island')

# %%
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', col = 'island', hue='island')
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter', col = 'island',hue='species')

# %%
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', col = 'sex', hue='body_mass_g')
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter', col = 'island',hue='body_mass_g')

# %%
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', col = 'island', size='body_mass_g')
sns.relplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', kind = 'scatter', col = 'island',size='sex')

# %%
penguins.head(50)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
flights = sns.load_dataset('flights')
type(penguins)
# Out:
# pandas.core.frame.DataFrame

# %%
flights.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
sns.relplot(data=flights, x ='passengers', y = 'year', kind='line' )

# %%
penguins.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %%
sns.displot(data=penguins, x= 'flipper_length_mm', col='sex', color='black')

# %%
sns.displot(data=penguins, x= 'body_mass_g', kind='hist', hue='species')

# %%
sns.displot(data=penguins, x= 'body_mass_g', kind='hist', hue='species', col = 'sex', row = 'island')

# %%
sns.displot(data=penguins, x= 'body_mass_g', kind='kde', hue='species', col = 'sex', row = 'island')

# %%
sns.displot(data=penguins, x= 'body_mass_g', kind='kde', hue='species', col = 'sex', row = 'island', fill = True)

# %%
sns.displot(data=penguins, x= 'body_mass_g',y = 'bill_depth_mm')

# %%
sns.set_style('dark')
sns.displot(data=penguins, x= 'body_mass_g',y = 'bill_depth_mm', cbar = True)

# %%
sns.jointplot(data=penguins, x = 'bill_length_mm', y = 'flipper_length_mm', hue = 'species')

# %%
sns.pairplot(data=penguins, hue = 'species')

# %%
sns.catplot(data=penguins, x='species', y = 'flipper_length_mm', hue ='species')

# %%
sns.catplot(data=penguins, x='species', y = 'flipper_length_mm', hue ='species', kind = 'box')

# %%
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm')

# %%
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm', hue = 'island')

# %%
sns.set_style('darkgrid')
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm', hue = 'island')

# %%
sns.set_style('ticks')
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm', hue = 'island')

# %%
sns.set_style('whitegrid')
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm', hue = 'island')

# %%
sns.set_style('dark')
sns.lmplot(data=penguins, x='bill_length_mm', y = 'flipper_length_mm', hue = 'island')
